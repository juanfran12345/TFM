# %% [markdown]
# # MODELO PROPHET PARA EL CONTAMINANTE NO2 PARA BARCELONA
#
# Importamos las librerías y definimos las rutas.

# %%
from pathlib import Path
from sklearn.model_selection import ParameterGrid

import warnings
warnings.filterwarnings("ignore")

import logging
logging.getLogger("cmdstanpy").setLevel(logging.WARNING)
logging.getLogger("fbprophet").setLevel(logging.WARNING)

import matplotlib.pyplot as plt
from pylab import rcParams
plt.style.use("fivethirtyeight")
plt.rcParams["lines.linewidth"] = 1.5
light_style = {
    "figure.facecolor": "#d9effb",   
    "axes.facecolor": "#d9effb",
    "savefig.facecolor": "#d9effb",
    "axes.grid": True,
    "axes.grid.which": "both",
    "axes.spines.left": True,
    "axes.spines.right": True,
    "axes.spines.top": True,
    "axes.spines.bottom": True,
    "grid.color": "#a9d3f2",
    "grid.linewidth": "0.8",
    "text.color": "#333333",
    "axes.labelcolor": "#333333",
    "axes.labelweight": "black",      
    "xtick.color": "#333333",
    "ytick.color": "#333333",
    "font.size": 12,
    "axes.titleweight": "bold",      
    "legend.fontsize": 12,
    "legend.title_fontsize": 12,
}
plt.rcParams.update(light_style)
rcParams["figure.figsize"] = (18, 7)


import sys
import importlib
from pathlib import Path

SCRIPTS_PATH = Path.cwd().parents[2]

if str(SCRIPTS_PATH) not in sys.path:
    sys.path.append(str(SCRIPTS_PATH))

import utils

importlib.reload(utils)

from utils import CARGA_Y_FILTRO, GRAFICAR_ESTACIONALIDADES, EVALUAR_METRICAS, CALCULAR_VIF, BUSQUEDA_CONFIGURACIONES_PROPHET, ENTRENAR_EVALUAR_PROPHET
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
BASE_PATH = Path("..", "..", "..", "..")
FOLDER_FIGS = BASE_PATH / "figuras" / "Modelado" / "Barcelona"
FOLDER_FIGS.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Cargamos los datos y filtramos las columnas que realmente necesitamos y como ciudad elegimos únicamente Barcelona.

# %%
df1 = CARGA_Y_FILTRO(
    contaminante="NO2 (ug.m-3)",
    ciudad="Barcelona"
)

# %% [markdown]
# ## Análisis exploratorio de las estacionalidades

# %%
fig, axes = GRAFICAR_ESTACIONALIDADES(
    df=df1,
    contaminante='NO2 (ug.m-3)',
    ciudad="Barcelona",
    nombre_contaminante="NO2",
    unidad="µg/m³"
)

fig.savefig(
    FOLDER_FIGS / "estacionalidades_NO2_Barcelona.png",
    dpi=300,                
    bbox_inches='tight',   
    facecolor='white'      
)

plt.show()

# %% [markdown]
# - Estacionalidad anual: sí, cada 12 meses.
# - Estacionalidad semanal: sí, cada 7 días.
# - Estacionalidad diaria: sí, cada 24 horas.

# %% [markdown]
# ## División del conjunto de datos

# %%
# ==============================================================================
# División cronológica del conjunto de datos
# ==============================================================================

train = df1[df1["Año"] <= 2020].copy()

validation = df1[
    (df1["Año"] >= 2021) &
    (df1["Año"] <= 2022)
].copy()

test = df1[df1["Año"] >= 2023].copy()

print(f"Entrenamiento: {train['Start'].min()} -> {train['Start'].max()}")
print(f"Validación:    {validation['Start'].min()} -> {validation['Start'].max()}")
print(f"Prueba:        {test['Start'].min()} -> {test['Start'].max()}")

print()
print(f"Nº muestras entrenamiento: {len(train):,}")
print(f"Nº muestras validación:    {len(validation):,}")
print(f"Nº muestras prueba:        {len(test):,}")
# Out:
# Entrenamiento: 2013-01-01 01:00:00 -> 2020-12-31 23:00:00
# Validación:    2021-01-01 00:00:00 -> 2022-12-31 23:00:00
# Prueba:        2023-01-01 00:00:00 -> 2024-12-31 23:00:00
#
# Nº muestras entrenamiento: 70,122
# Nº muestras validación:    17,520
# Nº muestras prueba:        17,544

# %%
train = train.rename(columns={"Start": "ds", "NO2 (ug.m-3)": "y"})
validation = validation.rename(columns={"Start": "ds", "NO2 (ug.m-3)": "y"})
test = test.rename(columns={"Start": "ds", "NO2 (ug.m-3)": "y"})

# %% [markdown]
# ## Elección de variables exógenas

# %%
multi = [
    "y",
    "temperature_2m",
    "relative_humidity_2m",
    "precipitation",
    "rain",
    "snowfall",
    "surface_pressure",
    "cloudcover",
    "windspeed_10m",
    "shortwave_radiation",
    "boundary_layer_height",
    "NDVI",
    "NDBI"
]

vif_exogenas = CALCULAR_VIF(
    datos=train,
    variables=multi
)

vif_exogenas
# Out:
#                  variable       VIF
# 0                    rain       inf
# 1           precipitation       inf
# 2                snowfall       inf
# 3   boundary_layer_height  2.894902
# 4     shortwave_radiation  2.662631
# 5    relative_humidity_2m  2.402819
# 6          temperature_2m  1.846946
# 7           windspeed_10m  1.753337
# 8                    NDVI  1.369770
# 9                       y  1.244641
# 10       surface_pressure  1.213362
# 11             cloudcover  1.180492
# 12                   NDBI  1.058462

# %%
multi1 = [
    "y",
    "temperature_2m",
    "relative_humidity_2m",
    "precipitation",
    "surface_pressure",
    "cloudcover",
    "windspeed_10m",
    "shortwave_radiation",
    "boundary_layer_height",
    "NDVI",
    "NDBI"
]

vif_exogenas1 = CALCULAR_VIF(
    datos=train,
    variables=multi1
)

vif_exogenas1
# Out:
#                  variable       VIF
# 0   boundary_layer_height  2.894685
# 1     shortwave_radiation  2.662584
# 2    relative_humidity_2m  2.402791
# 3          temperature_2m  1.844085
# 4           windspeed_10m  1.753292
# 5                    NDVI  1.369765
# 6                       y  1.244630
# 7        surface_pressure  1.212144
# 8              cloudcover  1.180326
# 9           precipitation  1.107482
# 10                   NDBI  1.058434

# %%
variables_exogenas1 = multi1.copy()
variables_exogenas1.remove("y")

# %% [markdown]
# ## Selección de los mejores hiperparámetros

# %%
# Lista de columnas que quieres mantener
columnas = ['ds', 'y'] + variables_exogenas1

train = train[columnas]
validation = validation[columnas]

# %% [markdown]
# ### Definición del espacio de búsqueda

# %%
# ==============================================================================
# Valores candidatos de los hiperparámetros
# ==============================================================================

param_grid = {
    
    # Flexibilidad de la tendencia
    "changepoint_prior_scale": [
        0.005,
        0.05,
        0.5
    ],

    # Parte inicial de la serie en la que se colocan los puntos de cambio
    "changepoint_range": [
        0.70,
        0.80,
        0.90
    ],

    # Intensidad de las estacionalidades
    "seasonality_prior_scale": [
        0.05,
        1.0
    ],

    # Tipo de estacionalidad
    "seasonality_mode": [
       "additive",
        "multiplicative"
    ],

    # Tipo de crecimiento
    "growth": [
       "linear",
        "logistic"
    ],

    # Número de términos de Fourier de la estacionalidad anual
    "yearly_seasonality": [
        5,
        10,
        20
    ],

    # Número de términos de Fourier de la estacionalidad diaria
    "daily_seasonality": [
        5,
        10,
        20
    ],

    # Número de términos de Fourier de la estacionalidad semanal
    "weekly_seasonality": [
        5,
        10,
        20
    ],

    # Incorporación de festivos nacionales de España
    "usar_festivos": [
        False,
        True
    ]
}

# %% [markdown]
# ### Búsqueda del mejor modelo

# %%
# ==============================================================================
# Límites para los modelos con crecimiento logístico
# ==============================================================================

capacidad = train["y"].max() * 1.20

print(
    "Capacidad utilizada para el crecimiento logístico: "
    f"{capacidad:.6f}"
)

# ==============================================================================
# Generación de todas las combinaciones posibles
# ==============================================================================

configuraciones = list(
    ParameterGrid(param_grid)
)

print(
    f"Número total de configuraciones que se evaluarán: "
    f"{len(configuraciones)}"
)
# Out:
# Capacidad utilizada para el crecimiento logístico: 529.920000
# Número total de configuraciones que se evaluarán: 3888

# %%
(
    resultados_df,
    resultados_correctos,
    mejor_resultado,
    mejor_modelo
) = BUSQUEDA_CONFIGURACIONES_PROPHET(
    configuraciones=configuraciones,
    variables_exogenas=variables_exogenas1,
    train=train,
    validation=validation,
    estacionalidades=[
        "yearly",
        "weekly",
        "daily"
    ],
    capacidad=capacidad
)
# Out:
# Estacionalidades utilizadas:
# - yearly
# - weekly
# - daily
#
# Mejores parámetros:
#
# changepoint_prior_scale: 0.5
# changepoint_range: 0.7
# seasonality_prior_scale: 1.0
# seasonality_mode: multiplicative
# growth: logistic
# usar_festivos: True
# yearly_seasonality: 10
# daily_seasonality: 20
# weekly_seasonality: 20
#
# MSE de validación: 412.7143

# %%
# Mejores parámetros obtenidos tras la búsqueda de hiperparámetros

mejores_parametros = {
    "changepoint_prior_scale": 0.5,
    "changepoint_range": 0.7,
    "seasonality_prior_scale": 1.0,
    "seasonality_mode": "multiplicative",
    "growth": "logistic",
    "usar_festivos": True,
    "yearly_seasonality": 10,
    "daily_seasonality": 20,
    "weekly_seasonality": 20
}

# %%
(
    modelo_prophet,
    prediccion_validacion,
    metricas_validacion,
    train_prophet_final,
    validation_prophet_final
) = ENTRENAR_EVALUAR_PROPHET(
    train=train,
    validation=validation,
    variables_exogenas=variables_exogenas1,
    mejores_parametros=mejores_parametros
)
# Out:
# Resultados de la evaluación del modelo
# ---------------------------------------
# Error absoluto medio (MAE): 5.47103
# Error cuadrático medio (MSE): 412.7143
# Raíz del error cuadrático medio (RMSE): 20.31537
# Error porcentual absoluto medio (MAPE): 20.61 %
# Raíz del error cuadrático medio normalizada (NRMSE): 74.33 %
